# %%
employees = [['Jonh Smith', '0899889368', 1500],
             ['Marry Simons', '0E54854869', 2500],
             ['', '01892142GG', 100],
             ['Adam Blackkkkkkkkkkkkkkkkkkk', '0988869689', 1200],
             ['Henry Dawnson','0977628282',900],
             ['','0986568685',500]
             ]

# %%
def clean_employees(employees,fix_name, fix_phone,fix_salary):
    for e in employees:
        fix_name(e)
        fix_phone(e)
        fix_salary(e)

# %%
def fix_empty_name(e):
    if e[0]=='':
        e[0]= 'Jonh Doe'
def fix_nothing(e):
    pass
clean_employees(employees, fix_empty_name,fix_nothing,fix_nothing)
print(employees)
# Out:
# [['Jonh Smith', '0899889368', 1500], ['Marry Simons', '0E54854869', 2500], ['Jonh Doe', '01892142GG', 100], ['Adam Blackkkkkkkkkkkkkkkkkkk', '0988869689', 1200], ['Henry Dawnson', '0977628282', 900], ['Jonh Doe', '0986568685', 500]]

# %%
def fix_tolong_name(e):
    if len(e[0]) > 20:
        e[0] = e[0][:20]

clean_employees(employees, fix_empty_name, fix_tolong_name, fix_nothing)
print(employees)
# Out:
# [['Jonh Smith', '0899889368', 1500], ['Marry Simons', '0E54854869', 2500], ['Jonh Doe', '01892142GG', 100], ['Adam Blackkkkkkkkkkk', '0988869689', 1200], ['Henry Dawnson', '0977628282', 900], ['Jonh Doe', '0986568685', 500]]

# %%
def fix_phone_number(e):
    phone = [c if c.isdigit() else '0' for c in e[1]]
    e[1] = ''.join(phone)

clean_employees(employees, fix_nothing, fix_phone_number, fix_nothing)
print(employees)
# Out:
# [['Jonh Smith', '0899889368', 1500], ['Marry Simons', '0054854869', 2500], ['Jonh Doe', '0189214200', 100], ['Adam Blackkkkkkkkkkk', '0988869689', 1200], ['Henry Dawnson', '0977628282', 900], ['Jonh Doe', '0986568685', 500]]

# %%
#e) Valid salary is in range [200, 2000]. 
# Any invalid salary should change to 200 or 2000 

def fix_salary(e):
    if e[2]>2000:
        e[2]=2000
    elif e[2]<200:
        e[2]=200
clean_employees(employees, fix_nothing, fix_nothing, fix_salary)
print(employees)
# Out:
# [['Jonh Smith', '0899889368', 1500], ['Marry Simons', '0054854869', 2000], ['Jonh Doe', '0189214200', 200], ['Adam Blackkkkkkkkkkk', '0988869689', 1200], ['Henry Dawnson', '0977628282', 900], ['Jonh Doe', '0986568685', 500]]

# %%
# f) Valid salary is in range [200, 2000].
# Any invalid salary should change to mean of valid salary

valid_salaries = [e[2] for e in employees if 200 <= e[2] <= 2000]
mean = sum(valid_salaries)/len(valid_salaries)

def fix_salary_by_meam(e):
    if e[2] < 200 or e[2] > 2000:
        e[2] = mean
clean_employees(employees, fix_nothing, fix_nothing, fix_salary_by_meam)
print(employees)
# Out:
# [['Jonh Smith', '0899889368', 1500], ['Marry Simons', '0E54854869', 1025.0], ['', '01892142GG', 1025.0], ['Adam Blackkkkkkkkkkkkkkkkkkk', '0988869689', 1200], ['Henry Dawnson', '0977628282', 900], ['', '0986568685', 500]]

# %%
# d) Phone must be digits, any non-digit should change to a previous digit (or 0 if not)
def fix_phone_last_digit(e):
    phone = ['0']+[c for c in e[1]]
    for i in range(len(phone)):
        if not phone[i].isdigit():
            phone[i] = phone[i-1]
    e[1] = ''.join(phone[1:])


clean_employees(employees, fix_nothing, fix_phone_last_digit, fix_nothing)
print(employees)
# Out:
# [['Jonh Smith', '0899889368', 1500], ['Marry Simons', '0054854869', 2500], ['', '0189214222', 100], ['Adam Blackkkkkkkkkkkkkkkkkkk', '0988869689', 1200], ['Henry Dawnson', '0977628282', 900], ['', '0986568685', 500]]

# %%
def my_sort(items, compare= lambda x,y:x>y):
    for i in range(len(items)-1):
        for j in range(i+1, len(items)):
            if compare(items[i], items[j]):
                items[i],items[j]=items[j],items[i]

# %%
import numpy as np
numbers = np.random.randint(10, 100, 20)
print(numbers)
my_sort(numbers)
print(numbers)
my_sort(numbers, lambda x, y: x < y)
print(numbers)
# Sort ascending by last digit
my_sort(numbers, lambda x, y: x % 10 > y % 10)
print(numbers)
# Sort descending by last digit
my_sort(numbers, lambda x, y: x % 10 < y % 10)
print(numbers)

# Sort ascending by sum of digit

my_sort(numbers, lambda x, y: x % 10+x//10 > y % 10+y//10)
print(numbers)
# Out:
# [83 78 54 90 27 48 82 52 10 37 55 41 56 11 40 71 27 47 18 36]
# [10 11 18 27 27 36 37 40 41 47 48 52 54 55 56 71 78 82 83 90]
# [90 83 82 78 71 56 55 54 52 48 47 41 40 37 36 27 27 18 11 10]
# [90 40 10 71 11 41 82 52 83 54 55 56 36 27 27 37 47 18 48 78]
# [18 48 78 47 27 27 37 36 56 55 54 83 82 52 41 71 11 10 90 40]
# [10 11 40 41 52 71 27 27 36 54 90 18 37 82 55 83 47 56 48 78]

# %%
names = ['Jonh', 'Ronaldo CR7', 'Marray MacHai',
         'Marry', 'Henery', 'Cong Tang Ton Nu Nguyen Thi Hoa']

print(names)

# sort ascending by length
my_sort(names, lambda x, y: len(x) > len(y))
print(names)
# sort descending by length
my_sort(names, lambda x, y: len(x) < len(y))
print(names)
# sort ascending by last name
my_sort(names, lambda x, y: x.split()[-1] > y.split()[-1])
print(names)
# #sort descending by last name
my_sort(names, lambda x, y: x.split()[-1] < y.split()[-1])
print(names)
# sort ascending by number of words
my_sort(names, lambda x, y: len(x.split()) > len(y.split()))
print(names)

# sort desscending by number of words
my_sort(names, lambda x, y: len(x.split()) < len(y.split()))
print(names)
# Out:
# ['Jonh', 'Ronaldo CR7', 'Marray MacHai', 'Marry', 'Henery', 'Cong Tang Ton Nu Nguyen Thi Hoa']
# ['Jonh', 'Marry', 'Henery', 'Ronaldo CR7', 'Marray MacHai', 'Cong Tang Ton Nu Nguyen Thi Hoa']
# ['Cong Tang Ton Nu Nguyen Thi Hoa', 'Marray MacHai', 'Ronaldo CR7', 'Henery', 'Marry', 'Jonh']
# ['Ronaldo CR7', 'Henery', 'Cong Tang Ton Nu Nguyen Thi Hoa', 'Jonh', 'Marray MacHai', 'Marry']
# ['Marry', 'Marray MacHai', 'Jonh', 'Cong Tang Ton Nu Nguyen Thi Hoa', 'Henery', 'Ronaldo CR7']
# ['Marry', 'Jonh', 'Henery', 'Marray MacHai', 'Ronaldo CR7', 'Cong Tang Ton Nu Nguyen Thi Hoa']
# ['Cong Tang Ton Nu Nguyen Thi Hoa', 'Ronaldo CR7', 'Marray MacHai', 'Marry', 'Jonh', 'Henery']

# %%
# Fillter: remove all items that do to satisfy a condition keep the rest
# Syntax: filter(f,iterable)
print(numbers)
evens = list(filter(lambda x: x % 2 == 0, numbers))
print(evens)
odds = list(filter(lambda x: x % 2 == 1, numbers))
print(odds)
# Out:
# [10 11 40 41 52 71 27 27 36 54 90 18 37 82 55 83 47 56 48 78]
# [10, 40, 52, 36, 54, 90, 18, 82, 56, 48, 78]
# [11, 41, 71, 27, 27, 37, 55, 83, 47]

# %%
# Function map: apply a function to each item of an iterable to change it
# Syntax: map(f, iterable)
print(numbers)
squares = list(map(lambda x: x**2,numbers))
print(squares)
# Out:
# [10 11 40 41 52 71 27 27 36 54 90 18 37 82 55 83 47 56 48 78]
# [100, 121, 1600, 1681, 2704, 5041, 729, 729, 1296, 2916, 8100, 324, 1369, 6724, 3025, 6889, 2209, 3136, 2304, 6084]

# %%
# random 100 float numer in rang [-1,1]

numbers = np.random.rand(100)*2-1

# plot number
import matplotlib.pyplot as plt
plt.plot(numbers)

# %%
new_number =list(map(lambda x:1 if x>=0 else -1, numbers))
plt.plot(new_number)

# %%
numbers = np.random.randint(-99,100,20)
#Convert negative number to positive numbers
new_number =list(map(lambda x:-x if x<0 else x, numbers))

print(numbers)
print(new_number)
plt.plot(new_number)
# Out:
# [ 12 -89 -10  91   1 -29 -61  70 -80 -34 -70  64 -17  25  91   5 -13  38
#   90  84]
# [12, 89, 10, 91, 1, 29, 61, 70, 80, 34, 70, 64, 17, 25, 91, 5, 13, 38, 90, 84]

# %%
# Find min amnog positive numbers, max of negative numbers
print(min(filter(lambda x: x > 0, numbers)))
print(max(filter(lambda x: x < 0, numbers)))
# Out:
# 9
# -9
